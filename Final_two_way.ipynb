# %%
import numpy as np
import pandas as pd
from patsy import dmatrices
from itertools import combinations
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Load the dataset
df=pd.read_csv('Final_Cleaned.csv')


df = df.drop(columns=['ID'])


df = df.rename(columns={'T Score': 'T_Score', 'Vit D': 'Vit_D'})

df = df.dropna()


predictor_columns = ['Gender', 'Age', 'BMD', 'T_Score', 'DM', 'HTN', 'Vit_D', 'Calcium', 'Menopause']


main_effects = ' + '.join(predictor_columns)
interaction_terms = ' + '.join([f'{a}:{b}' for a, b in combinations(predictor_columns, 2)])
formula = f'Diagnosis ~ {main_effects} + {interaction_terms}'


y, X = dmatrices(formula, df, return_type='dataframe')


vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)


y_bin = label_binarize(df['Diagnosis'], classes=['Normal', 'Penia', 'Porosis'])


model = make_pipeline(StandardScaler(), LogisticRegression(multi_class='ovr', solver='lbfgs', C=1.0, max_iter=1000))
model.fit(X, df['Diagnosis'])


probs = model.predict_proba(X)


probs_df = pd.DataFrame(probs, columns=model.classes_)


auc_scores = []
for i, class_name in enumerate(model.classes_):
    auc = roc_auc_score(y_bin[:, i], probs_df[class_name])
    auc_scores.append(auc)

average_auc = np.mean(auc_scores)

print(f'AUC scores for each class: {auc_scores}')
print(f'Average AUC score: {average_auc}')
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#               feature          VIF
# 0           Intercept     0.000000
# 1         Gender[T.M]          inf
# 2           DM[T.Pre]          inf
# 3   DM[T.Unavailable]          inf
# 4           DM[T.Yes]          inf
# ..                ...          ...
# 94          BMD:Vit_D   296.536550
# 95        BMD:Calcium  2926.321699
# 96      T_Score:Vit_D    68.066479
# 97    T_Score:Calcium  2985.393815
# 98      Vit_D:Calcium   555.770246
#
# [99 rows x 2 columns]
# AUC scores for each class: [0.9416780045351474, 0.8091863729618831, 0.8589909648069756]
# Average AUC score: 0.8699517807680021

# %%
#Odds ratio
log_reg = model.named_steps['logisticregression']
coefs = log_reg.coef_

odds_ratios = np.exp(coefs)
conf_intervals = []
for i in range(coefs.shape[0]):
    conf = []
    for j in range(coefs.shape[1]):
        coef = coefs[i, j]
        std_error = np.std(coefs[:, j])
        ci_lower = coef - 1.96 * std_error
        ci_upper = coef + 1.96 * std_error
        conf.append((np.exp(ci_lower), np.exp(ci_upper)))
    conf_intervals.append(conf)


for i, class_name in enumerate(model.classes_):
    print(f'Odds Ratios for class {class_name}:')
    for j, col in enumerate(X.design_info.column_names):
        print(f'{col}: OR={odds_ratios[i, j]:.4f}')
# Out:
# Odds Ratios for class Normal:
# Intercept: OR=1.0000
# Gender[T.M]: OR=1.0043
# DM[T.Pre]: OR=0.9977
# DM[T.Unavailable]: OR=0.9199
# DM[T.Yes]: OR=0.9667
# HTN[T.Unavailable]: OR=1.1245
# HTN[T.Yes]: OR=0.8932
# Menopause[T.Not Applicable]: OR=1.0043
# Menopause[T.Unknown]: OR=1.2357
# Menopause[T.Yes]: OR=0.6743
# Gender[T.M]:DM[T.Pre]: OR=1.0000
# Gender[T.M]:DM[T.Unavailable]: OR=0.9487
# Gender[T.M]:DM[T.Yes]: OR=0.8336
# Gender[T.M]:HTN[T.Unavailable]: OR=0.9487
# Gender[T.M]:HTN[T.Yes]: OR=1.3851
# Gender[T.M]:Menopause[T.Not Applicable]: OR=1.0043
# Gender[T.M]:Menopause[T.Unknown]: OR=1.0000
# Gender[T.M]:Menopause[T.Yes]: OR=1.0000
# DM[T.Pre]:HTN[T.Unavailable]: OR=1.6216
# DM[T.Unavailable]:HTN[T.Unavailable]: OR=0.8245
# DM[T.Yes]:HTN[T.Unavailable]: OR=1.1389
# DM[T.Pre]:HTN[T.Yes]: OR=0.8916
# DM[T.Unavailable]:HTN[T.Yes]: OR=1.0902
# DM[T.Yes]:HTN[T.Yes]: OR=0.7494
# DM[T.Pre]:Menopause[T.Not Applicable]: OR=1.0000
# DM[T.Unavailable]:Menopause[T.Not Applicable]: OR=0.9487
# DM[T.Yes]:Menopause[T.Not Applicable]: OR=0.8336
# DM[T.Pre]:Menopause[T.Unknown]: OR=1.1890
# DM[T.Unavailable]:Menopause[T.Unknown]: OR=1.2898
# DM[T.Yes]:Menopause[T.Unknown]: OR=1.2674
# DM[T.Pre]:Menopause[T.Yes]: OR=0.9311
# DM[T.Unavailable]:Menopause[T.Yes]: OR=0.8588
# DM[T.Yes]:Menopause[T.Yes]: OR=0.8573
# HTN[T.Unavailable]:Menopause[T.Not Applicable]: OR=0.9487
# HTN[T.Yes]:Menopause[T.Not Applicable]: OR=1.3851
# HTN[T.Unavailable]:Menopause[T.Unknown]: OR=1.2898
# HTN[T.Yes]:Menopause[T.Unknown]: OR=0.7164
# HTN[T.Unavailable]:Menopause[T.Yes]: OR=1.0657
# HTN[T.Yes]:Menopause[T.Yes]: OR=0.8255
# Age: OR=0.6758
# Gender[T.M]:Age: OR=0.7534
# Age:DM[T.Pre]: OR=0.9492
# Age:DM[T.Unavailable]: OR=0.8784
# Age:DM[T.Yes]: OR=2.6168
# Age:HTN[T.Unavailable]: OR=0.9705
# Age:HTN[T.Yes]: OR=1.4673
# Age:Menopause[T.Not Applicable]: OR=0.7534
# Age:Menopause[T.Unknown]: OR=0.7839
# Age:Menopause[T.Yes]: OR=1.0241
# BMD: OR=2.7400
# Gender[T.M]:BMD: OR=1.1949
# BMD:DM[T.Pre]: OR=1.0229
# BMD:DM[T.Unavailable]: OR=1.1893
# BMD:DM[T.Yes]: OR=0.8328
# BMD:HTN[T.Unavailable]: OR=1.0417
# BMD:HTN[T.Yes]: OR=1.2563
# BMD:Menopause[T.Not Applicable]: OR=1.1949
# BMD:Menopause[T.Unknown]: OR=1.3262
# BMD:Menopause[T.Yes]: OR=0.7053
# T_Score: OR=1.5253
# Gender[T.M]:T_Score: OR=1.0601
# T_Score:DM[T.Pre]: OR=1.1381
# T_Score:DM[T.Unavailable]: OR=1.1346
# T_Score:DM[T.Yes]: OR=0.6923
# T_Score:HTN[T.Unavailable]: OR=1.4034
# T_Score:HTN[T.Yes]: OR=1.2192
# T_Score:Menopause[T.Not Applicable]: OR=1.0601
# T_Score:Menopause[T.Unknown]: OR=1.1372
# T_Score:Menopause[T.Yes]: OR=0.8498
# Vit_D: OR=0.8691
# Gender[T.M]:Vit_D: OR=0.6760
# DM[T.Pre]:Vit_D: OR=0.8058
# DM[T.Unavailable]:Vit_D: OR=1.0152
# DM[T.Yes]:Vit_D: OR=0.7951
# HTN[T.Unavailable]:Vit_D: OR=0.5370
# HTN[T.Yes]:Vit_D: OR=1.1052
# Vit_D:Menopause[T.Not Applicable]: OR=0.6760
# Vit_D:Menopause[T.Unknown]: OR=0.5160
# Vit_D:Menopause[T.Yes]: OR=1.6156
# Calcium: OR=0.7277
# Gender[T.M]:Calcium: OR=0.8579
# DM[T.Pre]:Calcium: OR=0.9994
# DM[T.Unavailable]:Calcium: OR=0.9280
# DM[T.Yes]:Calcium: OR=0.9747
# HTN[T.Unavailable]:Calcium: OR=1.1141
# HTN[T.Yes]:Calcium: OR=0.6145
# Calcium:Menopause[T.Not Applicable]: OR=0.8579
# Calcium:Menopause[T.Unknown]: OR=1.0825
# Calcium:Menopause[T.Yes]: OR=0.8018
# Age:BMD: OR=1.4773
# Age:T_Score: OR=1.0807
# Age:Vit_D: OR=0.7907
# Age:Calcium: OR=0.5749
# BMD:T_Score: OR=0.7626
# BMD:Vit_D: OR=0.7944
# BMD:Calcium: OR=2.2202
# T_Score:Vit_D: OR=0.9230
# T_Score:Calcium: OR=1.5025
# Vit_D:Calcium: OR=1.2082
# Odds Ratios for class Penia:
# Intercept: OR=1.0000
# Gender[T.M]: OR=0.9125
# DM[T.Pre]: OR=0.8816
# DM[T.Unavailable]: OR=1.1917
# DM[T.Yes]: OR=0.9611
# HTN[T.Unavailable]: OR=0.8892
# HTN[T.Yes]: OR=0.9620
# Menopause[T.Not Applicable]: OR=0.9125
# Menopause[T.Unknown]: OR=1.1908
# Menopause[T.Yes]: OR=1.0861
# Gender[T.M]:DM[T.Pre]: OR=1.0000
# Gender[T.M]:DM[T.Unavailable]: OR=0.8666
# Gender[T.M]:DM[T.Yes]: OR=0.9405
# Gender[T.M]:HTN[T.Unavailable]: OR=0.8666
# Gender[T.M]:HTN[T.Yes]: OR=0.9578
# Gender[T.M]:Menopause[T.Not Applicable]: OR=0.9125
# Gender[T.M]:Menopause[T.Unknown]: OR=1.0000
# Gender[T.M]:Menopause[T.Yes]: OR=1.0000
# DM[T.Pre]:HTN[T.Unavailable]: OR=0.7640
# DM[T.Unavailable]:HTN[T.Unavailable]: OR=1.1401
# DM[T.Yes]:HTN[T.Unavailable]: OR=0.8096
# DM[T.Pre]:HTN[T.Yes]: OR=0.8532
# DM[T.Unavailable]:HTN[T.Yes]: OR=1.1212
# DM[T.Yes]:HTN[T.Yes]: OR=1.1594
# DM[T.Pre]:Menopause[T.Not Applicable]: OR=1.0000
# DM[T.Unavailable]:Menopause[T.Not Applicable]: OR=0.8666
# DM[T.Yes]:Menopause[T.Not Applicable]: OR=0.9405
# DM[T.Pre]:Menopause[T.Unknown]: OR=0.9694
# DM[T.Unavailable]:Menopause[T.Unknown]: OR=0.8338
# DM[T.Yes]:Menopause[T.Unknown]: OR=0.8438
# DM[T.Pre]:Menopause[T.Yes]: OR=0.8846
# DM[T.Unavailable]:Menopause[T.Yes]: OR=1.3357
# DM[T.Yes]:Menopause[T.Yes]: OR=1.0662
# HTN[T.Unavailable]:Menopause[T.Not Applicable]: OR=0.8666
# HTN[T.Yes]:Menopause[T.Not Applicable]: OR=0.9578
# HTN[T.Unavailable]:Menopause[T.Unknown]: OR=0.8338
# HTN[T.Yes]:Menopause[T.Unknown]: OR=0.9699
# HTN[T.Unavailable]:Menopause[T.Yes]: OR=0.9760
# HTN[T.Yes]:Menopause[T.Yes]: OR=0.9888
# Age: OR=0.8186
# Gender[T.M]:Age: OR=1.0888
# Age:DM[T.Pre]: OR=0.7862
# Age:DM[T.Unavailable]: OR=0.5956
# Age:DM[T.Yes]: OR=0.6552
# Age:HTN[T.Unavailable]: OR=1.2007
# Age:HTN[T.Yes]: OR=0.5930
# Age:Menopause[T.Not Applicable]: OR=1.0888
# Age:Menopause[T.Unknown]: OR=1.1422
# Age:Menopause[T.Yes]: OR=0.8948
# BMD: OR=0.7165
# Gender[T.M]:BMD: OR=0.7378
# BMD:DM[T.Pre]: OR=0.9591
# BMD:DM[T.Unavailable]: OR=0.8808
# BMD:DM[T.Yes]: OR=0.6356
# BMD:HTN[T.Unavailable]: OR=1.2630
# BMD:HTN[T.Yes]: OR=0.9843
# BMD:Menopause[T.Not Applicable]: OR=0.7378
# BMD:Menopause[T.Unknown]: OR=1.0254
# BMD:Menopause[T.Yes]: OR=1.6371
# T_Score: OR=1.5306
# Gender[T.M]:T_Score: OR=1.5269
# T_Score:DM[T.Pre]: OR=0.6043
# T_Score:DM[T.Unavailable]: OR=0.7169
# T_Score:DM[T.Yes]: OR=1.0776
# T_Score:HTN[T.Unavailable]: OR=1.6907
# T_Score:HTN[T.Yes]: OR=1.1408
# T_Score:Menopause[T.Not Applicable]: OR=1.5269
# T_Score:Menopause[T.Unknown]: OR=1.1791
# T_Score:Menopause[T.Yes]: OR=2.7874
# Vit_D: OR=0.9181
# Gender[T.M]:Vit_D: OR=1.0478
# DM[T.Pre]:Vit_D: OR=1.2598
# DM[T.Unavailable]:Vit_D: OR=0.9697
# DM[T.Yes]:Vit_D: OR=2.2744
# HTN[T.Unavailable]:Vit_D: OR=1.1833
# HTN[T.Yes]:Vit_D: OR=1.0530
# Vit_D:Menopause[T.Not Applicable]: OR=1.0478
# Vit_D:Menopause[T.Unknown]: OR=0.9659
# Vit_D:Menopause[T.Yes]: OR=0.6476
# Calcium: OR=0.9734
# Gender[T.M]:Calcium: OR=1.7838
# DM[T.Pre]:Calcium: OR=0.9807
# DM[T.Unavailable]:Calcium: OR=1.3039
# DM[T.Yes]:Calcium: OR=1.0951
# HTN[T.Unavailable]:Calcium: OR=0.8592
# HTN[T.Yes]:Calcium: OR=1.8470
# Calcium:Menopause[T.Not Applicable]: OR=1.7838
# Calcium:Menopause[T.Unknown]: OR=0.8383
# Calcium:Menopause[T.Yes]: OR=0.8383
# Age:BMD: OR=1.4265
# Age:T_Score: OR=2.9446
# Age:Vit_D: OR=1.4229
# Age:Calcium: OR=1.3801
# BMD:T_Score: OR=0.0523
# BMD:Vit_D: OR=1.4347
# BMD:Calcium: OR=0.6973
# T_Score:Vit_D: OR=1.4284
# T_Score:Calcium: OR=1.2840
# Vit_D:Calcium: OR=0.7462
# Odds Ratios for class Porosis:
# Intercept: OR=1.0000
# Gender[T.M]: OR=1.1157
# DM[T.Pre]: OR=1.1130
# DM[T.Unavailable]: OR=0.9103
# DM[T.Yes]: OR=1.1136
# HTN[T.Unavailable]: OR=0.9259
# HTN[T.Yes]: OR=1.0667
# Menopause[T.Not Applicable]: OR=1.1157
# Menopause[T.Unknown]: OR=0.7958
# Menopause[T.Yes]: OR=1.4932
# Gender[T.M]:DM[T.Pre]: OR=1.0000
# Gender[T.M]:DM[T.Unavailable]: OR=1.1792
# Gender[T.M]:DM[T.Yes]: OR=1.2882
# Gender[T.M]:HTN[T.Unavailable]: OR=1.1792
# Gender[T.M]:HTN[T.Yes]: OR=0.8173
# Gender[T.M]:Menopause[T.Not Applicable]: OR=1.1157
# Gender[T.M]:Menopause[T.Unknown]: OR=1.0000
# Gender[T.M]:Menopause[T.Yes]: OR=1.0000
# DM[T.Pre]:HTN[T.Unavailable]: OR=0.8375
# DM[T.Unavailable]:HTN[T.Unavailable]: OR=0.9966
# DM[T.Yes]:HTN[T.Unavailable]: OR=0.9980
# DM[T.Pre]:HTN[T.Yes]: OR=1.1914
# DM[T.Unavailable]:HTN[T.Yes]: OR=0.8751
# DM[T.Yes]:HTN[T.Yes]: OR=1.1462
# DM[T.Pre]:Menopause[T.Not Applicable]: OR=1.0000
# DM[T.Unavailable]:Menopause[T.Not Applicable]: OR=1.1792
# DM[T.Yes]:Menopause[T.Not Applicable]: OR=1.2882
# DM[T.Pre]:Menopause[T.Unknown]: OR=0.8294
# DM[T.Unavailable]:Menopause[T.Unknown]: OR=0.9786
# DM[T.Yes]:Menopause[T.Unknown]: OR=0.8866
# DM[T.Pre]:Menopause[T.Yes]: OR=1.2082
# DM[T.Unavailable]:Menopause[T.Yes]: OR=0.8645
# DM[T.Yes]:Menopause[T.Yes]: OR=1.0415
# HTN[T.Unavailable]:Menopause[T.Not Applicable]: OR=1.1792
# HTN[T.Yes]:Menopause[T.Not Applicable]: OR=0.8173
# HTN[T.Unavailable]:Menopause[T.Unknown]: OR=0.9786
# HTN[T.Yes]:Menopause[T.Unknown]: OR=1.3382
# HTN[T.Unavailable]:Menopause[T.Yes]: OR=0.8781
# HTN[T.Yes]:Menopause[T.Yes]: OR=1.0987
# Age: OR=1.2898
# Gender[T.M]:Age: OR=1.2814
# Age:DM[T.Pre]: OR=1.1956
# Age:DM[T.Unavailable]: OR=1.7186
# Age:DM[T.Yes]: OR=0.8882
# Age:HTN[T.Unavailable]: OR=0.8291
# Age:HTN[T.Yes]: OR=1.5002
# Age:Menopause[T.Not Applicable]: OR=1.2814
# Age:Menopause[T.Unknown]: OR=0.9870
# Age:Menopause[T.Yes]: OR=1.1567
# BMD: OR=0.4652
# Gender[T.M]:BMD: OR=1.0521
# BMD:DM[T.Pre]: OR=1.0734
# BMD:DM[T.Unavailable]: OR=0.7649
# BMD:DM[T.Yes]: OR=1.5258
# BMD:HTN[T.Unavailable]: OR=0.7926
# BMD:HTN[T.Yes]: OR=0.9024
# BMD:Menopause[T.Not Applicable]: OR=1.0521
# BMD:Menopause[T.Unknown]: OR=0.8271
# BMD:Menopause[T.Yes]: OR=1.1259
# T_Score: OR=0.6689
# Gender[T.M]:T_Score: OR=0.7209
# T_Score:DM[T.Pre]: OR=1.9483
# T_Score:DM[T.Unavailable]: OR=1.4200
# T_Score:DM[T.Yes]: OR=0.8603
# T_Score:HTN[T.Unavailable]: OR=0.5836
# T_Score:HTN[T.Yes]: OR=0.8527
# T_Score:Menopause[T.Not Applicable]: OR=0.7209
# T_Score:Menopause[T.Unknown]: OR=0.9146
# T_Score:Menopause[T.Yes]: OR=0.6960
# Vit_D: OR=1.2259
# Gender[T.M]:Vit_D: OR=0.9835
# DM[T.Pre]:Vit_D: OR=0.9650
# DM[T.Unavailable]:Vit_D: OR=0.9168
# DM[T.Yes]:Vit_D: OR=0.4257
# HTN[T.Unavailable]:Vit_D: OR=1.3458
# HTN[T.Yes]:Vit_D: OR=0.7466
# Vit_D:Menopause[T.Not Applicable]: OR=0.9835
# Vit_D:Menopause[T.Unknown]: OR=1.5365
# Vit_D:Menopause[T.Yes]: OR=1.2384
# Calcium: OR=1.3639
# Gender[T.M]:Calcium: OR=0.7197
# DM[T.Pre]:Calcium: OR=1.0067
# DM[T.Unavailable]:Calcium: OR=0.8443
# DM[T.Yes]:Calcium: OR=0.9825
# HTN[T.Unavailable]:Calcium: OR=0.9615
# HTN[T.Yes]:Calcium: OR=0.7138
# Calcium:Menopause[T.Not Applicable]: OR=0.7197
# Calcium:Menopause[T.Unknown]: OR=1.3337
# Calcium:Menopause[T.Yes]: OR=1.4843
# Age:BMD: OR=0.7802
# Age:T_Score: OR=0.7395
# Age:Vit_D: OR=0.8454
# Age:Calcium: OR=0.8005
# BMD:T_Score: OR=2.6746
# BMD:Vit_D: OR=0.7929
# BMD:Calcium: OR=0.8928
# T_Score:Vit_D: OR=0.7972
# T_Score:Calcium: OR=1.1227
# Vit_D:Calcium: OR=1.1284
